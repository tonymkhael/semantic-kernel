# %% [markdown]
# # Setup
#
# **Step 1**: Import Semantic Kernel SDK from pypi.org

# %%
# !python -m pip install semantic-kernel==0.9.6b1
# Out:
# Collecting semantic-kernel==0.9.6b1
#   Obtaining dependency information for semantic-kernel==0.9.6b1 from https://files.pythonhosted.org/packages/9c/e1/2c3754c0a6d6dcf8df2c12e9dfa95932c7d516599730f7cb5cbc5aca252b/semantic_kernel-0.9.6b1-py3-none-any.whl.metadata
#   Downloading semantic_kernel-0.9.6b1-py3-none-any.whl.metadata (5.2 kB)
# Collecting aiohttp<4.0,>=3.8 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for aiohttp<4.0,>=3.8 from https://files.pythonhosted.org/packages/a0/00/cdbda8b406ce7b656b9cb765f8134b1edb999f816f54e47347d2bc67f4bf/aiohttp-3.9.5-cp312-cp312-win_amd64.whl.metadata
#   Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl.metadata (7.7 kB)
# Collecting defusedxml<0.8.0,>=0.7.1 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for defusedxml<0.8.0,>=0.7.1 from https://files.pythonhosted.org/packages/07/6c/aa3f2f849e01cb6a001cd8554a88d4c77c5c1a31c95bdf1cf9301e6d9ef4/defusedxml-0.7.1-py2.py3-none-any.whl.metadata
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting grpcio>=1.50.0 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for grpcio>=1.50.0 from https://files.pythonhosted.org/packages/97/88/b8794e6270f3ca3efc1602ddb9f2f4c3eeb59a8523bb94a594ec2a768ba8/grpcio-1.62.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading grpcio-1.62.2-cp312-cp312-win_amd64.whl.metadata (4.2 kB)
# Collecting jinja2<4.0.0,>=3.1.3 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for jinja2<4.0.0,>=3.1.3 from https://files.pythonhosted.org/packages/30/6d/6de6be2d02603ab56e72997708809e8a5b0fbfee080735109b40a3564843/Jinja2-3.1.3-py3-none-any.whl.metadata
#   Downloading Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting motor<4.0.0,>=3.3.2 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for motor<4.0.0,>=3.3.2 from https://files.pythonhosted.org/packages/c1/94/e09b22a1501ac8960de4d6ff4e8d21fb7ef67063a3f4454823886fee43b5/motor-3.4.0-py3-none-any.whl.metadata
#   Downloading motor-3.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in c:\users\azureuser\appdata\roaming\python\python312\site-packages (from semantic-kernel==0.9.6b1) (1.6.0)
# Collecting numpy>=1.26 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for numpy>=1.26 from https://files.pythonhosted.org/packages/16/2e/86f24451c2d530c88daf997cb8d6ac622c1d40d19f5a031ed68a4b73a374/numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.4 MB/s eta 0:00:00
# Collecting openai>=1.0 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for openai>=1.0 from https://files.pythonhosted.org/packages/e2/40/9a2ad9fd5f1015d0dcbd19c7c9b1d72ab7174dfed593c5ec7e11ca82680e/openai-1.23.6-py3-none-any.whl.metadata
#   Downloading openai-1.23.6-py3-none-any.whl.metadata (21 kB)
# Collecting openapi_core<0.20,>=0.18 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for openapi_core<0.20,>=0.18 from https://files.pythonhosted.org/packages/b4/69/3d32f212887e9d6f5eaef23841a56976f398b26f77ae3aeca4bf95f1b0aa/openapi_core-0.19.1-py3-none-any.whl.metadata
#   Downloading openapi_core-0.19.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting prance<24.0.0.0,>=23.6.21.0 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for prance<24.0.0.0,>=23.6.21.0 from https://files.pythonhosted.org/packages/c9/db/4fb4901ee61274d0ab97746461fc5f2637e5d73aa73f34ee28e941a699a1/prance-23.6.21.0-py3-none-any.whl.metadata
#   Downloading prance-23.6.21.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4<0.10.0,>=0.9.13 (from semantic-kernel==0.9.6b1)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pydantic<3,>=2 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for pydantic<3,>=2 from https://files.pythonhosted.org/packages/ed/76/9a17032880ed27f2dbd490c77a3431cbc80f47ba81534131de3c2846e736/pydantic-2.7.1-py3-none-any.whl.metadata
#   Downloading pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
#      ---------------------------------------- 0.0/107.3 kB ? eta -:--:--
#      ---------------------------------------- 107.3/107.3 kB ? eta 0:00:00
# Collecting python-dotenv<2.0.0,>=1.0.1 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for python-dotenv<2.0.0,>=1.0.1 from https://files.pythonhosted.org/packages/6a/3e/b68c118422ec867fa7ab88444e1274aa40681c606d59ac27de5a5588f082/python_dotenv-1.0.1-py3-none-any.whl.metadata
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting regex<2024.0.0,>=2023.6.3 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for regex<2024.0.0,>=2023.6.3 from https://files.pythonhosted.org/packages/1d/af/4bd17254cdda1d8092460ee5561f013c4ca9c33ecf1aab81b44280327cab/regex-2023.12.25-cp312-cp312-win_amd64.whl.metadata
#   Downloading regex-2023.12.25-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB ? eta 0:00:00
# Collecting scipy>=1.12.0 (from semantic-kernel==0.9.6b1)
#   Obtaining dependency information for scipy>=1.12.0 from https://files.pythonhosted.org/packages/ed/6f/ba2b2f14391291dd47d17da78c3ee644fb3a2fd6bddde664381c1968eda9/scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB ? eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for aiosignal>=1.1.2 from https://files.pythonhosted.org/packages/76/ac/a7305707cb852b7e16ff80eaf5692309bde30e2b1100a1fcacdc8f731d97/aiosignal-1.3.1-py3-none-any.whl.metadata
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for attrs>=17.3.0 from https://files.pythonhosted.org/packages/e0/44/827b2a91a5816512fcaf3cc4ebc465ccd5d598c45cefa6703fcf4a79018f/attrs-23.2.0-py3-none-any.whl.metadata
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/3e/dc/96647994a013bc72f3d453abab18340b7f5e222b7b7291e3697ca1fcfbd5/frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for multidict<7.0,>=4.5 from https://files.pythonhosted.org/packages/4a/68/66fceb758ad7a88993940dbdf3ac59911ba9dc46d7798bf6c8652f89f853/multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata
#   Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0,>=3.8->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for yarl<2.0,>=1.0 from https://files.pythonhosted.org/packages/c5/f4/2fdc5a11503bc61818243653d836061c9ce0370e2dd9ac5917258a007675/yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<4.0.0,>=3.1.3->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/3f/14/c3554d512d5f9100a95e737502f4a2323a1959f6d0d01e0d0997b35f7b10/MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting pymongo<5,>=4.5 (from motor<4.0.0,>=3.3.2->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for pymongo<5,>=4.5 from https://files.pythonhosted.org/packages/27/76/ba4159a32342939df4af2a0028b3bac86cf3b88e8636ed74df7b3f18445a/pymongo-4.7.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading pymongo-4.7.0-cp312-cp312-win_amd64.whl.metadata (22 kB)
# Collecting anyio<5,>=3.5.0 (from openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for anyio<5,>=3.5.0 from https://files.pythonhosted.org/packages/14/fd/2f20c40b45e4fb4324834aea24bd4afdf1143390242c0b33774da0e2e34f/anyio-4.3.0-py3-none-any.whl.metadata
#   Downloading anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for httpx<1,>=0.23.0 from https://files.pythonhosted.org/packages/41/7b/ddacf6dcebb42466abd03f368782142baa82e08fc0c1f8eaa05b4bae87d5/httpx-0.27.0-py3-none-any.whl.metadata
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting sniffio (from openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for sniffio from https://files.pythonhosted.org/packages/e9/44/75a9c9421471a6c4805dbf2356f7c181a29c1879239abab1ea2cc8f38b40/sniffio-1.3.1-py3-none-any.whl.metadata
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for tqdm>4 from https://files.pythonhosted.org/packages/2a/14/e75e52d521442e2fcc9f1df3c5e456aead034203d4797867980de558ab34/tqdm-4.66.2-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.0 MB/s eta 0:00:00
# Collecting typing-extensions<5,>=4.7 (from openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for typing-extensions<5,>=4.7 from https://files.pythonhosted.org/packages/01/f3/936e209267d6ef7510322191003885de524fc48d1b43269810cd589ceaf5/typing_extensions-4.11.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting isodate (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for isodate from https://files.pythonhosted.org/packages/b6/85/7882d311924cbcfc70b1890780763e36ff0b140c7e51c110fc59a532f087/isodate-0.6.1-py2.py3-none-any.whl.metadata
#   Downloading isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Collecting jsonschema<5.0.0,>=4.18.0 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for jsonschema<5.0.0,>=4.18.0 from https://files.pythonhosted.org/packages/39/9d/b035d024c62c85f2e2d4806a59ca7b8520307f34e0932fbc8cc75fe7b2d9/jsonschema-4.21.1-py3-none-any.whl.metadata
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for jsonschema-path<0.4.0,>=0.3.1 from https://files.pythonhosted.org/packages/7f/5a/f405ced79c55191e460fc6d17a14845fddf09f601e39cfcab28cc1d3ff1c/jsonschema_path-0.3.2-py3-none-any.whl.metadata
#   Downloading jsonschema_path-0.3.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting more-itertools (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/50/e2/8e10e465ee3987bb7c9ab69efb91d867d93959095f4807db102d07995d94/more_itertools-10.2.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.2.0-py3-none-any.whl.metadata (34 kB)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for openapi-schema-validator<0.7.0,>=0.6.0 from https://files.pythonhosted.org/packages/b3/dc/9aefae8891454130968ff079ece851d1ae9ccf6fb7965761f47c50c04853/openapi_schema_validator-0.6.2-py3-none-any.whl.metadata
#   Downloading openapi_schema_validator-0.6.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for openapi-spec-validator<0.8.0,>=0.7.1 from https://files.pythonhosted.org/packages/2b/4d/e744fff95aaf3aeafc968d5ba7297c8cda0d1ecb8e3acd21b25adae4d835/openapi_spec_validator-0.7.1-py3-none-any.whl.metadata
#   Downloading openapi_spec_validator-0.7.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for parse from https://files.pythonhosted.org/packages/ce/f0/30fe1494f1910ad3ea40639b13ac48cdb16a8600e8861cbfc2c560661ddf/parse-1.20.1-py2.py3-none-any.whl.metadata
#   Downloading parse-1.20.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug (from openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for werkzeug from https://files.pythonhosted.org/packages/e3/23/c9843d7550092ae7ad380611c238f44afef66f58f76c1dab7dcf313e4339/werkzeug-3.0.2-py3-none-any.whl.metadata
#   Downloading werkzeug-3.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting chardet>=3.0 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for chardet>=3.0 from https://files.pythonhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting ruamel.yaml>=0.17.10 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for ruamel.yaml>=0.17.10 from https://files.pythonhosted.org/packages/73/67/8ece580cc363331d9a53055130f86b096bf16e38156e33b1d3014fffda6b/ruamel.yaml-0.18.6-py3-none-any.whl.metadata
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl.metadata (23 kB)
# Collecting requests>=2.25 (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for requests>=2.25 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six~=1.15 in c:\users\azureuser\appdata\roaming\python\python312\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1) (1.16.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\azureuser\appdata\roaming\python\python312\site-packages (from prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1) (24.0)
# Collecting PyMeta3>=0.5.1 (from pybars4<0.10.0,>=0.9.13->semantic-kernel==0.9.6b1)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=2->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=2->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for pydantic-core==2.18.2 from https://files.pythonhosted.org/packages/e4/49/f29028068b5cb364ad066a58490dd26fd1d4ba2943d829eb0f85dbc8ab06/pydantic_core-2.18.2-cp312-none-win_amd64.whl.metadata
#   Downloading pydantic_core-2.18.2-cp312-none-win_amd64.whl.metadata (6.7 kB)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for idna>=2.8 from https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl.metadata
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for certifi from https://files.pythonhosted.org/packages/ba/06/a07f096c664aeb9f01624f858c3add0a4e913d6c96257acb4fce61e7de14/certifi-2024.2.2-py3-none-any.whl.metadata
#   Downloading certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/78/d4/e5d7e4f2174f8a4d63c8897d79eb8fe2503f7ecc03282fee1fa2719c2704/httpcore-1.0.5-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for h11<0.15,>=0.13 from https://files.pythonhosted.org/packages/95/04/ff642e65ad6b90db43e668d70ffb6736436c7ce41fcc549f4e9472234127/h11-0.14.0-py3-none-any.whl.metadata
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/ee/07/44bd408781594c4d0a027666ef27fab1e441b109dc3b76b4f836f8fd04fe/jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/8f/ad/0a39c92d2d2769eb02adfdd50282e25341dccee3a14753c972d7327de664/referencing-0.35.0-py3-none-any.whl.metadata
#   Downloading referencing-0.35.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/14/8c/e69f5636f4ab6ee0855aef3b16e6c97f8b636e9e04fa5a4bcc75126acb13/rpds_py-0.18.0-cp312-none-win_amd64.whl.metadata
#   Downloading rpds_py-0.18.0-cp312-none-win_amd64.whl.metadata (4.2 kB)
# Collecting PyYAML>=5.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for PyYAML>=5.1 from https://files.pythonhosted.org/packages/2b/9f/fbade56564ad486809c27b322d0f7e6a89c01f6b4fe208402e90d4443a99/PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for pathable<0.5.0,>=0.4.1 from https://files.pythonhosted.org/packages/5b/0a/acfb251ba01009d3053f04f4661e96abf9d485266b04a0a4deebc702d9cb/pathable-0.4.3-py3-none-any.whl.metadata
#   Downloading pathable-0.4.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/ec/d8/e826b3f743d97e45d3ace674a5c6f026069428e608c5fde3d08d072c87f2/referencing-0.31.1-py3-none-any.whl.metadata
#   Downloading referencing-0.31.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for rfc3339-validator from https://files.pythonhosted.org/packages/7b/44/4e421b96b67b2daff264473f7465db72fbdf36a07e05494f50300cc7b0c6/rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for lazy-object-proxy<2.0.0,>=1.7.1 from https://files.pythonhosted.org/packages/77/ce/7956dc5ac2f8b62291b798c8363c81810e22a9effe469629d297d087e350/lazy_object_proxy-1.10.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading lazy_object_proxy-1.10.0-cp312-cp312-win_amd64.whl.metadata (8.1 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5,>=4.5->motor<4.0.0,>=3.3.2->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for dnspython<3.0.0,>=1.16.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for charset-normalizer<4,>=2 from https://files.pythonhosted.org/packages/b6/7c/8debebb4f90174074b827c63242c23851bdf00a532489fba57fef3416e40/charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.25->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for urllib3<3,>=1.21.1 from https://files.pythonhosted.org/packages/a2/73/a68704750a7679d0b6d3ad7aa8d4da8e14e151ae82e6fee774e6e0d05ec8/urllib3-2.2.1-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.10->prance<24.0.0.0,>=23.6.21.0->semantic-kernel==0.9.6b1)
#   Obtaining dependency information for ruamel.yaml.clib>=0.2.7 from https://files.pythonhosted.org/packages/10/d2/52a3d810d0b5b3720725c0504a27b3fced7b6f310fe928f7019d79387bc1/ruamel.yaml.clib-0.2.8-cp312-cp312-win_amd64.whl.metadata
#   Downloading ruamel.yaml.clib-0.2.8-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: colorama in c:\users\azureuser\appdata\roaming\python\python312\site-packages (from tqdm>4->openai>=1.0->semantic-kernel==0.9.6b1) (0.4.6)
# Downloading semantic_kernel-0.9.6b1-py3-none-any.whl (273 kB)
#    ---------------------------------------- 0.0/273.6 kB ? eta -:--:--
#    --------------------------------------- 273.6/273.6 kB 16.5 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp312-cp312-win_amd64.whl (369 kB)
#    ---------------------------------------- 0.0/369.0 kB ? eta -:--:--
#    --------------------------------------- 369.0/369.0 kB 22.4 MB/s eta 0:00:00
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading grpcio-1.62.2-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------  3.7/3.8 MB 116.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 79.7 MB/s eta 0:00:00
# Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.2 kB ? eta -:--:--
#    ---------------------------------------- 133.2/133.2 kB 8.2 MB/s eta 0:00:00
# Downloading motor-3.4.0-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/74.3 kB ? eta -:--:--
#    ---------------------------------------- 74.3/74.3 kB 4.0 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ------------- -------------------------- 5.0/15.5 MB 162.5 MB/s eta 0:00:01
#    ------------------------ --------------- 9.7/15.5 MB 123.8 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.5 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------  15.5/15.5 MB 131.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.5/15.5 MB 65.5 MB/s eta 0:00:00
# Downloading openai-1.23.6-py3-none-any.whl (311 kB)
#    ---------------------------------------- 0.0/311.6 kB ? eta -:--:--
#    ---------------------------------------- 311.6/311.6 kB ? eta 0:00:00
# Downloading openapi_core-0.19.1-py3-none-any.whl (103 kB)
#    ---------------------------------------- 0.0/103.1 kB ? eta -:--:--
#    ---------------------------------------- 103.1/103.1 kB 5.8 MB/s eta 0:00:00
# Downloading prance-23.6.21.0-py3-none-any.whl (36 kB)
# Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#    ---------------------------------------- 0.0/409.3 kB ? eta -:--:--
#    --------------------------------------- 409.3/409.3 kB 24.9 MB/s eta 0:00:00
# Downloading pydantic_core-2.18.2-cp312-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 61.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading regex-2023.12.25-cp312-cp312-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/268.9 kB ? eta -:--:--
#    ---------------------------------------- 268.9/268.9 kB ? eta 0:00:00
# Downloading scipy-1.13.0-cp312-cp312-win_amd64.whl (45.9 MB)
#    ---------------------------------------- 0.0/45.9 MB ? eta -:--:--
#    --- ------------------------------------ 4.1/45.9 MB 86.5 MB/s eta 0:00:01
#    -------- ------------------------------- 9.3/45.9 MB 119.5 MB/s eta 0:00:01
#    ----------- ---------------------------- 13.8/45.9 MB 131.2 MB/s eta 0:00:01
#    -------------- ------------------------- 17.0/45.9 MB 108.8 MB/s eta 0:00:01
#    ------------------- -------------------- 22.0/45.9 MB 108.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 27.4/45.9 MB 131.2 MB/s eta 0:00:01
#    --------------------------- ------------ 31.7/45.9 MB 108.8 MB/s eta 0:00:01
#    ------------------------------ --------- 35.4/45.9 MB 108.8 MB/s eta 0:00:01
#    --------------------------------- ------ 38.5/45.9 MB 110.0 MB/s eta 0:00:01
#    ------------------------------------- -- 43.4/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------  45.9/45.9 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------------- 45.9/45.9 MB 19.8 MB/s eta 0:00:00
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.6 kB ? eta -:--:--
#    ---------------------------------------- 85.6/85.6 kB 5.0 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#    ---------------------------------------- 60.8/60.8 kB 3.2 MB/s eta 0:00:00
# Downloading chardet-5.2.0-py3-none-any.whl (199 kB)
#    ---------------------------------------- 0.0/199.4 kB ? eta -:--:--
#    ---------------------------------------- 199.4/199.4 kB ? eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
#    ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#    ---------------------------------------- 50.5/50.5 kB 2.7 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.6 kB ? eta -:--:--
#    ---------------------------------------- 75.6/75.6 kB ? eta 0:00:00
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.9 kB ? eta -:--:--
#    ---------------------------------------- 77.9/77.9 kB 4.5 MB/s eta 0:00:00
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.5 kB ? eta -:--:--
#    ---------------------------------------- 85.5/85.5 kB 4.7 MB/s eta 0:00:00
# Downloading jsonschema_path-0.3.2-py3-none-any.whl (14 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading openapi_schema_validator-0.6.2-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.1-py3-none-any.whl (38 kB)
# Downloading pymongo-4.7.0-cp312-cp312-win_amd64.whl (485 kB)
#    ---------------------------------------- 0.0/485.1 kB ? eta -:--:--
#    --------------------------------------- 485.1/485.1 kB 29.7 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.6 kB ? eta -:--:--
#    ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.8 kB ? eta -:--:--
#    ---------------------------------------- 117.8/117.8 kB ? eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
#    ---------------------------------------- 0.0/76.4 kB ? eta -:--:--
#    ---------------------------------------- 76.4/76.4 kB 4.4 MB/s eta 0:00:00
# Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#    ---------------------------------------- 0.0/41.7 kB ? eta -:--:--
#    ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.0 kB ? eta -:--:--
#    ---------------------------------------- 57.0/57.0 kB ? eta 0:00:00
# Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Downloading werkzeug-3.0.2-py3-none-any.whl (226 kB)
#    ---------------------------------------- 0.0/226.8 kB ? eta -:--:--
#    --------------------------------------- 226.8/226.8 kB 13.5 MB/s eta 0:00:00
# Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#    ---------------------------------------- 0.0/163.8 kB ? eta -:--:--
#    ---------------------------------------- 163.8/163.8 kB 9.6 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
#    ---------------------------------------- 100.4/100.4 kB ? eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    --------------------------------------- 307.7/307.7 kB 18.6 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ---------------------------------------- 0.0/66.8 kB ? eta -:--:--
#    ---------------------------------------- 66.8/66.8 kB ? eta 0:00:00
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading lazy_object_proxy-1.10.0-cp312-cp312-win_amd64.whl (27 kB)
# Downloading pathable-0.4.3-py3-none-any.whl (9.6 kB)
# Downloading PyYAML-6.0.1-cp312-cp312-win_amd64.whl (138 kB)
#    ---------------------------------------- 0.0/138.7 kB ? eta -:--:--
#    ---------------------------------------- 138.7/138.7 kB 8.6 MB/s eta 0:00:00
# Downloading referencing-0.31.1-py3-none-any.whl (25 kB)
# Downloading rpds_py-0.18.0-cp312-none-win_amd64.whl (206 kB)
#    ---------------------------------------- 0.0/206.3 kB ? eta -:--:--
#    ---------------------------------------- 206.3/206.3 kB ? eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.8-cp312-cp312-win_amd64.whl (115 kB)
#    ---------------------------------------- 0.0/115.3 kB ? eta -:--:--
#    ---------------------------------------- 115.3/115.3 kB 6.6 MB/s eta 0:00:00
# Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/121.1 kB ? eta -:--:--
#    ---------------------------------------- 121.1/121.1 kB 7.4 MB/s eta 0:00:00
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#    ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#    ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (pyproject.toml): started
#   Building wheel for pybars4 (pyproject.toml): finished with status 'done'
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14349 sha256=1211b512e0c878fdc71da3d6127b63cfca089fea3ed0de8942c2c710b0250fdd
#   Stored in directory: c:\users\azureuser\appdata\local\pip\cache\wheels\75\2d\da\c75b2fc7b00dc9c154dff65f689a318e7d24b44c612c2b21f1
#   Building wheel for PyMeta3 (pyproject.toml): started
#   Building wheel for PyMeta3 (pyproject.toml): finished with status 'done'
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16487 sha256=75a7ce8b62d26cfe1b7dd00562567e2ac37f7bd43aa15da67d1fb72fc4f19a53
#   Stored in directory: c:\users\azureuser\appdata\local\pip\cache\wheels\5a\9b\2c\81b7551d2c05a482817e6c3b3d2f8ad2a0229db874c4bc6346
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, urllib3, typing-extensions, tqdm, sniffio, ruamel.yaml.clib, rpds-py, rfc3339-validator, regex, PyYAML, python-dotenv, pybars4, pathable, numpy, multidict, more-itertools, MarkupSafe, lazy-object-proxy, isodate, idna, h11, grpcio, frozenlist, dnspython, distro, defusedxml, charset-normalizer, chardet, certifi, attrs, annotated-types, yarl, werkzeug, scipy, ruamel.yaml, requests, referencing, pymongo, pydantic-core, jinja2, httpcore, anyio, aiosignal, pydantic, prance, motor, jsonschema-specifications, jsonschema-path, httpx, aiohttp, openai, jsonschema, openapi-schema-validator, openapi-spec-validator, openapi_core, semantic-kernel
# Successfully installed MarkupSafe-2.1.5 PyMeta3-0.5.1 PyYAML-6.0.1 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.6.0 anyio-4.3.0 attrs-23.2.0 certifi-2024.2.2 chardet-5.2.0 charset-normalizer-3.3.2 defusedxml-0.7.1 distro-1.9.0 dnspython-2.6.1 frozenlist-1.4.1 grpcio-1.62.2 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.7 isodate-0.6.1 jinja2-3.1.3 jsonschema-4.21.1 jsonschema-path-0.3.2 jsonschema-specifications-2023.12.1 lazy-object-proxy-1.10.0 more-itertools-10.2.0 motor-3.4.0 multidict-6.0.5 numpy-1.26.4 openai-1.23.6 openapi-schema-validator-0.6.2 openapi-spec-validator-0.7.1 openapi_core-0.19.1 parse-1.20.1 pathable-0.4.3 prance-23.6.21.0 pybars4-0.9.13 pydantic-2.7.1 pydantic-core-2.18.2 pymongo-4.7.0 python-dotenv-1.0.1 referencing-0.31.1 regex-2023.12.25 requests-2.31.0 rfc3339-validator-0.1.4 rpds-py-0.18.0 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 scipy-1.13.0 semantic-kernel-0.9.6b1 sniffio-1.3.1 tqdm-4.66.2 typing-extensions-4.11.0 urllib3-2.2.1 werkzeug-3.0.2 yarl-1.9.4
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from semantic_kernel import Kernel

kernel = Kernel()

# %% [markdown]
# ### Configure the service you'd like to use via the `Service` Enum.

# %%
from services import Service

# Select a service to use for this notebook (available services: OpenAI, AzureOpenAI, HuggingFace)
selectedService = Service.AzureOpenAI

# %% [markdown]
# ## Option 1: using OpenAI
#
# **Step 2**: Add your [OpenAI Key](https://openai.com/product/) key to a `.env` file in the same folder (org Id only if you have multiple orgs):
#
# ```
# OPENAI_API_KEY="sk-..."
# OPENAI_ORG_ID=""
# ```
#
# Use "keyword arguments" to instantiate an OpenAI Chat Completion service and add it to the kernel:
#
# ## Option 2: using Azure OpenAI
#
# **Step 2**: Add your [Azure Open AI Service key](https://learn.microsoft.com/azure/cognitive-services/openai/quickstart?pivots=programming-language-studio) settings to a `.env` file in the same folder:
#
# ```
# AZURE_OPENAI_API_KEY="..."
# AZURE_OPENAI_ENDPOINT="https://..."
# AZURE_OPENAI_DEPLOYMENT_NAME="..."
# ```
#
# Use "keyword arguments" to instantiate an Azure OpenAI Chat Completion service and add it to the kernel:

# %%
from semantic_kernel.utils.settings import azure_openai_settings_from_dot_env, openai_settings_from_dot_env

service_id = None
if selectedService == Service.OpenAI:
    from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion

    api_key, org_id = openai_settings_from_dot_env()
    service_id = "default"
    kernel.add_service(
        OpenAIChatCompletion(service_id=service_id, ai_model_id="gpt-3.5-turbo-1106", api_key=api_key, org_id=org_id),
    )
elif selectedService == Service.AzureOpenAI:
    from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

    deployment, api_key, endpoint = azure_openai_settings_from_dot_env()
    service_id = "default"
    kernel.add_service(
        AzureChatCompletion(service_id=service_id, deployment_name=deployment, endpoint=endpoint, api_key=api_key),
    )

# %% [markdown]
# # Run a Semantic Function
#
# **Step 3**: Load a Plugin and run a semantic function:

# %%
plugin = kernel.add_plugin(parent_directory="../../samples/plugins", plugin_name="FunPlugin")

# %%
from semantic_kernel.functions import KernelArguments

joke_function = plugin["Joke"]

joke = await kernel.invoke(joke_function, KernelArguments(input="time travel to dinosaur age", style="super silly"))
print(joke)
# Out:
# Why did the T-Rex refuse to go on a date with the Stegosaurus? Because he knew it would be a Jurassic disappointment! Super silly, I know, but it still makes me laugh every time I think about it.
